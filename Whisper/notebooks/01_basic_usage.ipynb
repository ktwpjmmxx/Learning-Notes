# %% [markdown]
# ### Google Colabを使用してWhisperのテスト
# **OpenAIのGitHubにアップロードされている"harvard.wav"の文字起こしをテスト**

# %% [markdown]
# #### 参考リンク：https://github.com/gloveboxes/OpenAI-Whisper-Transcriber-Sample/blob/master/harvard.wav

# %%
# !pip install -q openai-whisper
# !apt update && apt install -y ffmpeg

# %%
import os
os.environ["PATH"] += os.pathsep + "/usr/bin/"

# %%
# !wget -q "https://github.com/gloveboxes/OpenAI-Whisper-Transcriber-Sample/raw/master/harvard.wav" -O harvard_test.wav

# %%
# !ls -lh harvard_test.wav

# %%
import whisper
model = whisper.load_model("base")

# %%
print("--- 文字起こしを開始します ---")
result = model.transcribe("harvard_test.wav")
print("\n--- 結果 ---")
print(result["text"])
